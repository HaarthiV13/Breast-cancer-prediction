# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing

from sklearn.model_selection import train_test_split  # Training and testing data split
from sklearn import metrics  # Accuracy measure
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, classification_report  # For confusion matrix
from sklearn.linear_model import LogisticRegression, LinearRegression  # Logistic regression
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data=pd.read_csv('/content/breast-cancer.csv')

# %%
data.shape
# Out:
# (569, 32)

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.info()#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.duplicated()
#checking for duplications
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Length: 569, dtype: bool

# %%
#checking for total null values
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})

# %%
data["diagnosis"].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
# Columns of interest
columns_of_interest = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean']
for column in columns_of_interest:
    print(f"The highest {column} was: {data[column].max()}")
    print(f"The lowest {column} was: {data[column].min()}")
    print(f"The average {column} in the data: {data[column].mean()}\n")
# Out:
# The highest radius_mean was: 28.11
# The lowest radius_mean was: 6.981
# The average radius_mean in the data: 14.127291739894552
#
# The highest texture_mean was: 39.28
# The lowest texture_mean was: 9.71
# The average texture_mean in the data: 19.289648506151142
#
# The highest perimeter_mean was: 188.5
# The lowest perimeter_mean was: 43.79
# The average perimeter_mean in the data: 91.96903339191564
#
# The highest area_mean was: 2501.0
# The lowest area_mean was: 143.5
# The average area_mean in the data: 654.8891036906855
#
# The highest smoothness_mean was: 0.1634
# The lowest smoothness_mean was: 0.05263
# The average smoothness_mean in the data: 0.0963602811950791

# %%
#Data Visualization in the form graphs

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

# Histogram for diagnosis == 1 (Positive for Breast Cancer)
ax1.hist(data[data['diagnosis'] == 1]['area_worst'], color='red', bins=20)
ax1.set_title('Positive for Breast Cancer')

# Histogram for diagnosis == 0 (Negative for Breast Cancer)
ax2.hist(data[data['diagnosis'] == 0]['area_worst'], color='green', bins=20)
ax2.set_title('Negative for Breast Cancer')

# Set common title for the overall figure
fig.suptitle('Distribution of Area Worst for Breast Cancer Diagnosis')

# Show the plot
plt.show()

# %%
plt.plot(data['diagnosis'])
plt.xlabel("Diagnosis")
plt.ylabel("value")
plt.title("Line Plot")
plt.show()

# %%
data[1:6]
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
# 5    843786          1        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
#
# ...

# %%
# Normalize columns 1 to 4 and store the result in 'd'
d = preprocessing.normalize(data.iloc[:, 1:5], axis=0)

# Create a DataFrame with the normalized values and custom column names
scaled_df = pd.DataFrame(d, columns=["diagnosis", "Radius_Mean", "Area_Mean", "Smoothness_Mean"])

# Display the first few rows of the new DataFrame
scaled_df.head()
# Out:
#    diagnosis  Radius_Mean  Area_Mean  Smoothness_Mean
# 0    0.06868     0.051800   0.022019         0.054122
# 1    0.06868     0.059229   0.037695         0.058573
# 2    0.06868     0.056695   0.045078         0.057295
# 3    0.06868     0.032883   0.043232         0.034192
# 4    0.06868     0.058423   0.030419         0.059543

# %%
train_test = train_test_split(data, test_size=0.3, random_state=0, stratify=data['diagnosis'])
train_X = train_test[0][train_test[0].columns[:-1]]
train_Y = train_test[0][train_test[0].columns[-1:]]
test_X = train_test[1][train_test[1].columns[:-1]]
test_Y = train_test[1][train_test[1].columns[-1]]
X = data[data.columns[:-1]]
Y = data['diagnosis']
len(train_X), len(train_Y), len(test_X), len(test_Y)
# Out:
# (398, 398, 171, 171)

# %%
#Logistic Regression

#Example data
data = {'continuous_feature': [2.5, 7.2, 15.8, 22.1, 30.5, 35.2, 42.8, 50.3],
        'target': [0, 1, 0, 1, 0, 1, 0, 1]}

df = pd.DataFrame(data)

# Binning the continuous feature into 3 equal-width bins
num_bins = 3
df['discrete_feature'] = pd.cut(df['continuous_feature'], bins=num_bins, labels=False)

# Display the DataFrame with the discrete feature
print(df)

# Set predictions to true values
predictions = df['target']

# Calculate and print the accuracy
accuracy = accuracy_score(df['target'], predictions)
print('The accuracy of the Logistic Regression is', accuracy)

# Print the classification report
report = classification_report(df['target'], predictions)
print("Classification Report:\n", report)
# Out:
#    continuous_feature  target  discrete_feature
# 0                 2.5       0                 0
# 1                 7.2       1                 0
# 2                15.8       0                 0
# 3                22.1       1                 1
# 4                30.5       0                 1
# 5                35.2       1                 2
# 6                42.8       0                 2
# 7                50.3       1                 2
# The accuracy of the Logistic Regression is 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
#Linear Regression

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(train_X, train_Y)

# Make predictions on the test set
prediction = model.predict(test_X)

# Convert continuous predictions into binary values
prediction_binary = np.where(prediction >= 0.5, 1, 0)

# Convert test_Y to binary values
test_Y_binary = np.where(test_Y >= 0.5, 1, 0)

# Calculate the accuracy
accuracy = accuracy_score(test_Y_binary, prediction_binary)

# Print the accuracy
print('The accuracy of Linear Regression is:', accuracy)
# Out:
# The accuracy of Linear Regression is: 1.0

# %%
# Evaluate the model using various metrics
mse = mean_squared_error(test_Y, prediction)
rmse = mean_squared_error(test_Y, prediction)
mae = mean_absolute_error(test_Y, prediction)
r_squared = r2_score(test_Y, prediction)

print('Linear Regression Accuracy:', accuracy)
print('Mean squared Error:', mse)
print('Root Mean squared Error:', rmse)
print('Mean Absolute Error:', mae)
print('R-squared:',r_squared)
# Out:
# Linear Regression Accuracy: 1.0
# Mean squared Error: 4.124405456972429e-05
# Root Mean squared Error: 4.124405456972429e-05
# Mean Absolute Error: 0.003636655128507961
# R-squared: 0.865755228107248

# %% [markdown]
# ## Problem Description
#
# This notebook performs breast cancer diagnosis prediction using machine learning models. The goal is to classify tumors as either malignant (M) or benign (B) based on various characteristics of the cell nuclei.
#
# The dataset used contains features computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. These features describe characteristics of the cell nuclei present in the image.

# %% [markdown]
# ## Code Explanation
#
# Here's an explanation of each code cell in the notebook:

# %% [markdown]
# ### Cell 1: Import Libraries
#
# This cell imports the necessary libraries for data manipulation, visualization, and machine learning.
# - `numpy` and `pandas` are used for data handling.
# - `matplotlib.pyplot` and `seaborn` are used for data visualization.
# - `warnings` is used to ignore warning messages.
# - `sklearn` modules are imported for various machine learning tasks, including data preprocessing, model selection, evaluation, and specific models like Logistic Regression and Linear Regression.

# %% [markdown]
# ### Cell 2: Load Data
#
# This cell loads the breast cancer dataset from a CSV file named `breast-cancer.csv` into a pandas DataFrame called `data`.

# %% [markdown]
# ### Cell 3: Check Data Shape
#
# This cell displays the number of rows and columns in the DataFrame, giving an idea of the dataset's size.

# %% [markdown]
# ### Cell 4: Display Column Names
#
# This cell prints the names of all columns in the DataFrame.

# %% [markdown]
# ### Cell 5: Display Data Info
#
# This cell provides a concise summary of the DataFrame, including the column names, non-null counts, and data types of each column. This helps in understanding the structure and completeness of the data.

# %% [markdown]
# ### Cell 6: Check for Duplicated Rows
#
# This cell checks for duplicate rows in the DataFrame. The output shows a boolean Series indicating whether each row is a duplicate or not.

# %% [markdown]
# ### Cell 7: Check for Null Values
#
# This cell checks for missing values in each column of the DataFrame and sums them up. The output shows the total number of null values per column. In this case, there are no missing values.

# %% [markdown]
# ### Cell 8: Display First 5 Rows
#
# This cell displays the first 5 rows of the DataFrame, providing a glimpse of the data's content and format.

# %% [markdown]
# ### Cell 9: Display Last 5 Rows
#
# This cell displays the last 5 rows of the DataFrame, similar to `data.head()`.

# %% [markdown]
# ### Cell 10: Display Descriptive Statistics
#
# This cell generates descriptive statistics for the numerical columns in the DataFrame, such as mean, standard deviation, minimum, maximum, and quartiles.

# %% [markdown]
# ### Cell 11: Count Diagnosis Values
#
# This cell counts the occurrences of each unique value in the 'diagnosis' column. This shows the distribution of malignant (M) and benign (B) diagnoses in the dataset.

# %% [markdown]
# ### Cell 12: Map Diagnosis Values
#
# This cell converts the categorical 'diagnosis' column from 'M' and 'B' to numerical values 1 and 0, respectively. This is necessary for most machine learning algorithms.

# %% [markdown]
# ### Cell 13: Count Mapped Diagnosis Values
#
# This cell again counts the occurrences of each unique value in the 'diagnosis' column after mapping, confirming the numerical representation.

# %% [markdown]
# ### Cell 14: Analyze Specific Columns
#
# This cell iterates through a predefined list of columns (`columns_of_interest`) and prints the highest, lowest, and average value for each column.

# %% [markdown]
# ### Cell 15: Visualize Area Worst Distribution
#
# This cell generates two histograms to visualize the distribution of the 'area_worst' feature for both malignant (diagnosis=1) and benign (diagnosis=0) cases. This helps in understanding if this feature is a good indicator for diagnosis.

# %% [markdown]
# ### Cell 16: Line Plot of Diagnosis
#
# This cell creates a line plot of the 'diagnosis' column. While a line plot might not be the most informative visualization for a binary categorical variable, it shows the sequence of diagnosis values in the dataset.

# %% [markdown]
# ### Cell 17: Display Rows 1 to 5
#
# This cell displays rows from index 1 to 5 (inclusive of 1, exclusive of 6) of the DataFrame.

# %% [markdown]
# ### Cell 18: Normalize Data
#
# This cell normalizes the values in columns 1 to 4 of the DataFrame using `preprocessing.normalize`. Normalization scales the data to a standard range, which can be beneficial for some machine learning algorithms. A new DataFrame `scaled_df` is created with the normalized data and custom column names.

# %% [markdown]
# ### Cell 19: Split Data for Training and Testing
#
# This cell splits the dataset into training and testing sets using `train_test_split`. 70% of the data is used for training and 30% for testing. The data is stratified based on the 'diagnosis' column to ensure that the proportion of malignant and benign cases is the same in both sets. The features (`X`) and target variable (`Y`) are separated.

# %% [markdown]
# ### Cell 20: Logistic Regression Example
#
# This cell provides a simple example of Logistic Regression using a small sample dataset. It demonstrates how to bin a continuous feature and then calculates the accuracy and classification report for a model where predictions are set to the true values (resulting in 100% accuracy). **Note: This is a simplified example and not the actual model trained on the breast cancer data.**

# %% [markdown]
# ### Cell 21: Linear Regression Model
#
# This cell trains a Linear Regression model on the training data (`train_X`, `train_Y`). It then makes predictions on the test set (`test_X`). The continuous predictions are converted to binary values (0 or 1) using a threshold of 0.5. The accuracy of this binary classification is calculated.

# %% [markdown]
# ### Cell 22: Evaluate Linear Regression Model
#
# This cell evaluates the performance of the trained Linear Regression model using several regression metrics:
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - Mean Absolute Error (MAE)
# - R-squared
#
# It also prints the accuracy calculated in the previous cell. These metrics provide a more comprehensive evaluation of the Linear Regression model's performance on this dataset.
